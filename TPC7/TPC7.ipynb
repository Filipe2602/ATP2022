# %%
import csv
import aula
import menu

# %%
aluno=aula.leAlunos("alunos.csv")
aluno1=aula.medAlunos(aluno)
aluno2= aula.escaAlunos(aluno1)  



menu.menu()
# Out:
# | =============Menu============= |
# | (1) Ler informação             |
# | (2) Alunos por curso           |
# | (3) Média de notas             |
# | (4) Escalões                   |
# | (5) Escalões por alunos        |
# | (6) Gráfico                    |
# | (7) Tabela                     |
# | (0) Sair                       |
# | ============================== |
# |Curso:              |Número de alunos no curso:|
# |LEI                 |23                        |
# |ENGFIS              |32                        |
# |LCC                 |20                        |
# |ENGBIOM             |25                        |
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [2], line 7
#       2 aluno1=aula.medAlunos(aluno)
#       3 aluno2= aula.escaAlunos(aluno1)
# ----> 7 menu.menu()
#
# File c:\Users\Asus\Desktop\Programaçao\Aula 7\menu.py:32, in menu()
# ...
